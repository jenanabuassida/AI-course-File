# %% [markdown]
# # Iris project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# Import libraries for data visualization

# %%
# %matplotlib inline

# %% [markdown]
# For read the data from the file line by line

# %%
df_iris = pd.read_csv('iris-data.csv')

# %% [markdown]
#  Open the csv file and read data from it

# %%
df_iris
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0                5.1             3.5              1.4             0.2
# 1                4.9             3.0              1.4             0.2
# 2                4.7             3.2              1.3             0.2
# 3                4.6             3.1              1.5             0.2
# 4                5.0             3.6              1.4             0.2
# 5                5.4             3.9              1.7             0.4
# 6                4.6             3.4              1.4             0.3
# 7                5.0             3.4              1.5             NaN
# 8                4.4             2.9              1.4             NaN
# 9                4.9             3.1              1.5             NaN
# 10               5.4             3.7              1.5             NaN
# 11               4.8             3.4              1.6             NaN
# ...

# %% [markdown]
#  print the data in the csv file

# %%
df_versicolor_petal= df_iris[df_iris.iris_class == 'Iris-versicolor']

# %% [markdown]
#  take sublist of the list of data (just take records of one iris_class from the three) (take Iris-versicolor class)

# %%
df_versicolor_petal
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 50            7.000             3.2              4.7             1.4
# 51            6.400             3.2              4.5             1.5
# 52            6.900             3.1              4.9             1.5
# 53            5.500             2.3              4.0             1.3
# 54            6.500             2.8              4.6             1.5
# 55            5.700             2.8              4.5             1.3
# 56            6.300             3.3              4.7             1.6
# 57            4.900             2.4              3.3             1.0
# 58            6.600             2.9              4.6             1.3
# 59            5.200             2.7              3.9             1.4
# 60            5.000             2.0              3.5             1.0
# 61            5.900             3.0              4.2             1.5
# 62            6.000             2.2              4.0             1.0
# ...

# %% [markdown]
#  Print the taken sublist for Iris-versicolor class

# %%
df_virginica_petal= df_iris[df_iris.iris_class == 'Iris-virginica']

# %% [markdown]
# take sublist of the list of data (just take records of one iris_class from the three) (take Iris-virginica class)

# %%
df_virginica_petal
# Out:
#      sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 100              6.3             3.3              6.0             2.5
# 101              5.8             2.7              5.1             1.9
# 102              7.1             3.0              5.9             2.1
# 103              6.3             2.9              5.6             1.8
# 104              6.5             3.0              5.8             2.2
# 105              7.6             3.0              6.6             2.1
# 106              4.9             2.5              4.5             1.7
# 107              7.3             2.9              6.3             1.8
# 108              6.7             2.5              5.8             1.8
# 109              7.2             3.6              6.1             2.5
# 110              6.5             3.2              5.1             2.0
# 111              6.4             2.7              5.3             1.9
# ...

# %% [markdown]
#  Print the taken sublist for Iris-virginica class

# %%
df_setosa_petal= df_iris[df_iris.iris_class == 'Iris-setosa']

# %% [markdown]
#  take sublist of the list of data (just take records of one iris_class from the three) (take Iris-setosa class)

# %%
df_setosa_petal
# Out:
#     sepal_length_cm  sepal_width_cm  petal_length_cm  petal_width_cm  \
# 0               5.1             3.5              1.4             0.2
# 1               4.9             3.0              1.4             0.2
# 2               4.7             3.2              1.3             0.2
# 3               4.6             3.1              1.5             0.2
# 4               5.0             3.6              1.4             0.2
# 5               5.4             3.9              1.7             0.4
# 6               4.6             3.4              1.4             0.3
# 7               5.0             3.4              1.5             NaN
# 8               4.4             2.9              1.4             NaN
# 9               4.9             3.1              1.5             NaN
# 10              5.4             3.7              1.5             NaN
# 11              4.8             3.4              1.6             NaN
# 12              4.8             3.0              1.4             0.1
# ...

# %% [markdown]
# Print the taken sublist for Iris-setosa class

# %%
versicolor_petal_length=np.array(df_versicolor_petal['petal_length_cm'])
versicolor_petal_width=np.array(df_versicolor_petal['petal_width_cm'])

# %% [markdown]
# create two arrays for petal_length and petal_width in Iris-versicolor class

# %%
versicolor_petal_length
# Out:
# array([ 4.7,  4.5,  4.9,  4. ,  4.6,  4.5,  4.7,  3.3,  4.6,  3.9,  3.5,
#         4.2,  4. ,  4.7,  3.6,  4.4,  4.5,  4.1,  4.5,  3.9,  4.8,  4. ,
#         4.9,  4.7,  4.3,  4.4,  4.8,  5. ,  4.5,  3.5,  3.8,  3.7,  3.9,
#         5.1,  4.5,  4.5,  4.7,  4.4,  4.1,  4. ,  4.4,  4.6,  4. ,  3.3,
#         4.2,  4.2,  4.2,  4.3,  3. ,  4.1])

# %% [markdown]
# print the first array (array of length)

# %%
setosa_petal_length=np.array(df_setosa_petal['petal_length_cm'])
setosa_petal_width=np.array(df_setosa_petal['petal_width_cm'])

# %% [markdown]
#  create two arrays for petal_length and petal_width in Iris-setosa class

# %%
setosa_petal_length
# Out:
# array([ 1.4,  1.4,  1.3,  1.5,  1.4,  1.7,  1.4,  1.5,  1.4,  1.5,  1.5,
#         1.6,  1.4,  1.1,  1.2,  1.5,  1.3,  1.4,  1.5,  1.7,  1.5,  1. ,
#         1.7,  1.9,  1.6,  1.6,  1.5,  1.4,  1.6,  1.6,  1.5,  1.5,  1.4,
#         1.5,  1.2,  1.3,  1.5,  1.3,  1.5,  1.3,  1.3,  1.3,  1.6,  1.9,
#         1.4,  1.6,  1.4,  1.5,  1.4])

# %% [markdown]
# * print the first array (array of length)

# %%
virginica_petal_length=np.array(df_virginica_petal['petal_length_cm'])
virginica_petal_width=np.array(df_virginica_petal['petal_width_cm'])

# %% [markdown]
# create two arrays for petal_length and petal_width in Iris-virginica class

# %%
virginica_petal_length
# Out:
# array([ 6. ,  5.1,  5.9,  5.6,  5.8,  6.6,  4.5,  6.3,  5.8,  6.1,  5.1,
#         5.3,  5.5,  5. ,  5.1,  5.3,  5.5,  6.7,  6.9,  5. ,  5.7,  4.9,
#         6.7,  4.9,  5.7,  6. ,  4.8,  4.9,  5.6,  5.8,  6.1,  6.4,  5.6,
#         5.1,  5.6,  6.1,  5.6,  5.5,  4.8,  5.4,  5.6,  5.1,  5.1,  5.9,
#         5.7,  5.2,  5. ,  5.2,  5.4,  5.1])

# %% [markdown]
# print the first array (array of length)

# %%
differences_versicolor = versicolor_petal_length - np.mean(versicolor_petal_length )
diff_versicolor_sq = differences_versicolor**2
variance_versicolor_explicit = np.mean(diff_versicolor_sq)
variance_versicolor_np = np.var(versicolor_petal_length)
print(variance_versicolor_explicit, variance_versicolor_np)
# Out:
# 0.2164 0.2164

# %% [markdown]
#  Array of differences to mean: differences for class Iris-versicolor

# %%
differences_setosa = setosa_petal_length- np.mean(setosa_petal_length)
diff_setosa_sq = differences_setosa**2
variance_setosa_explicit = np.mean(diff_setosa_sq)
variance_setosa_np = np.var(setosa_petal_length)
print(variance_setosa_explicit, variance_setosa_np )
# Out:
# 0.0289462723865 0.0289462723865

# %% [markdown]
# Array of differences to mean: differences for class Iris-setosa

# %%
differences_virginica = virginica_petal_length - np.mean(virginica_petal_length )
diff_virginica_sq = differences_virginica**2
variance_virginica_explicit = np.mean(diff_virginica_sq)
variance_virginica_np = np.var(virginica_petal_length)
print(variance_virginica_explicit, variance_virginica_np)
# Out:
# 0.298496 0.298496

# %% [markdown]
#  Array of differences to mean: differences for class Iris-virginica

# %%
# Compute the variance: variance
variance_versicolor = np.var(versicolor_petal_length)

# Print the square root of the variance
print(np.sqrt(variance_versicolor))

# Print the standard deviation
print(np.std(versicolor_petal_length))
# Out:
# 0.465188133985
# 0.465188133985

# %% [markdown]
# Compute the variance: variance for class Iris-versicolor

# %%
# Compute the variance: variance
variance_setosa = np.var(setosa_petal_length)

# Print the square root of the variance
print(np.sqrt(variance_setosa))

# Print the standard deviation
print(np.std(setosa_petal_length))
# Out:
# 0.170136040822
# 0.170136040822

# %% [markdown]
#  Compute the variance: variance for class Iris-setosa

# %%
# Compute the variance: variance
variance_virginica = np.var( virginica_petal_length)

# Print the square root of the variance
print(np.sqrt(variance_virginica))

# Print the standard deviation
print(np.std( virginica_petal_length))
# Out:
# 0.546347874527
# 0.546347874527

# %% [markdown]
# Compute the variance: variance for class Iris-virginica

# %%
# Make a scatter plot
_ = plt.plot(versicolor_petal_length, versicolor_petal_width,
             marker='.', linestyle='none')

# Set margins
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('petal width (cm)')

# Show the result
plt.show()

# %% [markdown]
# Make a scatter plot for represent the relation between petal length and petal width in class Iris-versicolor

# %%
# Make a scatter plot
_ = plt.plot(setosa_petal_length, setosa_petal_width,
             marker='.', linestyle='none', color='red')

# Set margins
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('petal width (cm)')

# Show the result
plt.show()

# %% [markdown]
# Make a scatter plot for represent the relation between petal length and petal width in class Iris-setosa

# %%
# Make a scatter plot
_ = plt.plot( virginica_petal_length,  virginica_petal_width,
             marker='.', linestyle='none', color='green')

# Set margins
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('petal width (cm)')

# Show the result
plt.show()

# %% [markdown]
# Make a scatter plot for represent the relation between petal length and petal width in class Iris-virginica

# %%
# Make a scatter plot
_ = plt.plot( virginica_petal_length,  virginica_petal_width,
             marker='.', linestyle='none', color='green')
_ = plt.plot(setosa_petal_length, setosa_petal_width,
             marker='.', linestyle='none', color='red')
_ = plt.plot(versicolor_petal_length, versicolor_petal_width,
             marker='.', linestyle='none')

# Set margins
plt.margins(0.02)

# Label the axes
_ = plt.xlabel('petal length (cm)')
_ = plt.ylabel('petal width (cm)')

# Show the result
plt.show()

# %% [markdown]
# Make a scatter plot for represent the relation between petal length and petal width in the three classes

# %%
# Compute the covariance matrix: covariance_matrix
covariance_versicolor_matrix = np.cov(versicolor_petal_length, versicolor_petal_width)

# Print covariance matrix
print(covariance_versicolor_matrix)

# Extract covariance of length and width of petals: petal_cov
petal_versicolor_cov = covariance_versicolor_matrix[0,1]

# Print the length/width covariance
print(petal_versicolor_cov)
# Out:
# [[ 0.22081633  0.07310204]
#  [ 0.07310204  0.03910612]]
# 0.0731020408163

# %% [markdown]
# Compute the covariance matrix: covariance_matrix for class Iris-versicolor

# %%
# Compute the covariance matrix: covariance_matrix
covariance_virginica_matrix = np.cov(virginica_petal_length, virginica_petal_width)

# Print covariance matrix
print(covariance_virginica_matrix)

# Extract covariance of length and width of petals: petal_cov
petal_virginica_cov = covariance_virginica_matrix[0,1]

# Print the length/width covariance
print(petal_virginica_cov)
# Out:
# [[ 0.30458776  0.04431837]
#  [ 0.04431837  0.07657551]]
# 0.0443183673469

# %% [markdown]
#  Compute the covariance matrix: covariance_matrix for class Iris-virginica

# %%
# Compute the covariance matrix: covariance_matrix
covariance_setosa_matrix = np.cov(setosa_petal_length, setosa_petal_width)

# Print covariance matrix
print(covariance_setosa_matrix)

# Extract covariance of length and width of petals: petal_cov
petal_setosa_cov = covariance_setosa_matrix[0,1]

# Print the length/width covariance
print(petal_setosa_cov)
# Out:
# [[ 0.02954932         nan]
#  [        nan         nan]]
# nan

# %% [markdown]
# Compute the covariance matrix: covariance_matrix for class Iris-setosa

# %%
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays."""
    # Compute correlation matrix: corr_mat
    corr_mat = np.corrcoef(x, y)

    # Return entry [0,1]
    return corr_mat[0,1]

# Compute Pearson correlation coefficient for I. versicolor
r = pearson_r(versicolor_petal_width, versicolor_petal_length)

# Print the result
print(r)
# Out:
# 0.786668088523

# %% [markdown]
# Compute Pearson correlation coefficient between two arrays (array of lengthsarray of widths) to know the relationship between them in class Iris-versicolor

# %%
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays."""
    # Compute correlation matrix: corr_mat
    corr_mat = np.corrcoef(x, y)

    # Return entry [0,1]
    return corr_mat[0,1]

# Compute Pearson correlation coefficient for I. versicolor
r = pearson_r(virginica_petal_width, virginica_petal_length)

# Print the result
print(r)
# Out:
# 0.290190094146

# %% [markdown]
# Compute Pearson correlation coefficient between two arrays (array of lengths and array of widths) to know the relationship between them in class Iris-virginica

# %%
def pearson_r(x, y):
    """Compute Pearson correlation coefficient between two arrays."""
    # Compute correlation matrix: corr_mat
    corr_mat = np.corrcoef(x, y)

    # Return entry [0,1]
    return corr_mat[0,1]

# Compute Pearson correlation coefficient for I. versicolor
r = pearson_r(setosa_petal_width, setosa_petal_length)

# Print the result
print(r)
# Out:
# nan

# %% [markdown]
#  Compute Pearson correlation coefficient between two arrays (array of lengths and array of widths) to know the relationship between them in class Iris-setosa

# %%
def ecdf(data):
    """Compute ECDF for a one-dimensional array of measurements."""

    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %% [markdown]
#  Compute ECDF for a one-dimensional array of measurements. for the three classes because it is the same for all

# %%
vpetal_mean = np.mean(versicolor_petal_length)
vpetal_median = np.median(versicolor_petal_length)
vpetal_std = np.std(versicolor_petal_length)
x, y = ecdf(versicolor_petal_length)
_=plt.plot(x, y, marker='.', linestyle='none')
_=plt.plot((vpetal_mean,vpetal_mean),(0.1,0.9), marker='.', color = 'red')
_=plt.plot((vpetal_median,vpetal_median),(0.1,0.9), marker='_', color = 'black')
_=plt.plot((0,6),(vpetal_std, vpetal_std), marker='_', color = 'green')

_=plt.xlabel('versicolor_petal_length')
_=plt.ylabel('ECDF')
plt.show()

# %% [markdown]
# * create scatter plot for represent the relationship between the length (x exsit)  and ECDF (y exit) in Iris-versicolor class

# %%
vpetal_virginica_mean = np.mean(virginica_petal_length)
vpetal_virginica_median = np.median(virginica_petal_length)
vpetal_virginica_std = np.std(virginica_petal_length)
x, y = ecdf(virginica_petal_length)
_=plt.plot(x, y, marker='.', linestyle='none')
_=plt.plot((vpetal_virginica_mean,vpetal_virginica_mean),(0.1,0.9), marker='.', color = 'red')
_=plt.plot((vpetal_virginica_median,vpetal_virginica_median),(0.1,0.9), marker='_', color = 'black')
_=plt.plot((0,6),(vpetal_virginica_std, vpetal_virginica_std), marker='_', color = 'green')

_=plt.xlabel('virginica_petal_length')
_=plt.ylabel('ECDF')
plt.show()

# %% [markdown]
# * create scatter plot for represent the relationship between the length (x exsit) and ECDF (y exit) in Iris-virginica class

# %%
vpetal_setosa_mean = np.mean(setosa_petal_length)
vpetal_setosa_median = np.median(setosa_petal_length)
vpetal_setosa_std = np.std(setosa_petal_length)
x, y = ecdf(setosa_petal_length)
_=plt.plot(x, y, marker='.', linestyle='none')
_=plt.plot((vpetal_setosa_mean,vpetal_setosa_mean),(0.1,0.9), marker='.', color = 'red')
_=plt.plot((vpetal_setosa_median,vpetal_setosa_median),(0.1,0.9), marker='_', color = 'black')
_=plt.plot((0,6),(vpetal_setosa_std, vpetal_setosa_std), marker='_', color = 'green')
_=plt.xlabel('setosa_petal_length')
_=plt.ylabel('ECDF')
plt.show()

# %% [markdown]
# * create scatter plot for represent the relationship between the length (x exsit) and ECDF (y exit) in Iris-setosa class

# %%
vpetal_mean = np.mean(versicolor_petal_length)
vpetal_median = np.median(versicolor_petal_length)
vpetal_std = np.std(versicolor_petal_length)
x, y = ecdf(versicolor_petal_length)
_=plt.plot(x, y, marker='.', linestyle='none')
_=plt.plot((vpetal_mean,vpetal_mean),(0.1,0.9), marker='.', color = 'red')
_=plt.plot((vpetal_median,vpetal_median),(0.1,0.9), marker='_', color = 'black')
_=plt.plot((0,6),(vpetal_std, vpetal_std), marker='_', color = 'green')

vpetal_setosa_mean = np.mean(setosa_petal_length)
vpetal_setosa_median = np.median(setosa_petal_length)
vpetal_setosa_std = np.std(setosa_petal_length)
x, y = ecdf(setosa_petal_length)
_=plt.plot(x, y, marker='.', linestyle='none')
_=plt.plot((vpetal_setosa_mean,vpetal_setosa_mean),(0.1,0.9), marker='.', color = 'red')
_=plt.plot((vpetal_setosa_median,vpetal_setosa_median),(0.1,0.9), marker='_', color = 'black')
_=plt.plot((0,6),(vpetal_setosa_std, vpetal_setosa_std), marker='_', color = 'green')

vpetal_virginica_mean = np.mean(virginica_petal_length)
vpetal_virginica_median = np.median(virginica_petal_length)
vpetal_virginica_std = np.std(virginica_petal_length)
x, y = ecdf(virginica_petal_length)
_=plt.plot(x, y, marker='.', linestyle='none')
_=plt.plot((vpetal_virginica_mean,vpetal_virginica_mean),(0.1,0.9), marker='.', color = 'red')
_=plt.plot((vpetal_virginica_median,vpetal_virginica_median),(0.1,0.9), marker='_', color = 'black')
_=plt.plot((0,6),(vpetal_virginica_std, vpetal_virginica_std), marker='_', color = 'green')

_=plt.xlabel('versicolor_petal_length')
_=plt.ylabel('ECDF')
plt.show()

# %% [markdown]
#  create scatter plot for represent the relationship between the length (x exsit) and ECDF (y exit) in the three  class

# %% [markdown]
# we can use length to classcify the three types
